# %% [markdown]
# ## Skills paper
#
# write intro here
#
# Some useful links:
#
# https://qiita.com/takeshikondo/items/3aae12df9063c539b0ea
# http://proceedings.mlr.press/v54/newling17a/newling17a.pdf
# https://journals.sagepub.com/doi/pdf/10.1177/0962280215621591
# https://cran.r-project.org/web/packages/akmedoids/vignettes/akmedoids-vignette.html
# https://pubmed.ncbi.nlm.nih.gov/31781756/

# %% [markdown]
# ### Methods and data
#
# write methods here

# %% [markdown]
# ### Results
#
# write methods here

# %% [markdown]
# ##### import libraries
#
# pandas for data management, numpy and seaborn for analysis, matplotlib for visualization. Other libraries as needed for specific tasks (e.g. PAM).

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ##### read data
#
# read data files here (csv ideally but also dta if needed) using pandas (follow the notation on the example).

# %%
# higher ed data
cned = pd.read_csv('../data/cned.csv')
cned.dropna(inplace=True)

# %% [markdown]
# ##### example graph

# %%
# change plot size
cned.rename(columns={"puntaje": "score", "ingreso2": "enrollment"}, inplace=True)
scatter1 = sns.pairplot(x_vars="score", y_vars="enrollment", data=cned, hue="area", height=4)
